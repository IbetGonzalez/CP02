# %% [markdown]
# ---
# # Question 4
#
# Contributions from Question 4:
# - Jason Li: co-wrote and tested code
# - Monique Kubovsky: co-wrote and tested code

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import lagrange
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt

# %%
x = [4.0, 4.2, 4.5, 4.7, 5.1, 5.5, 5.9, 6.3, 6.8, 7.1]
n = len(x)
y = [102.56, 113.18, 130.11, 142.05, 167.53, 195.14, 224.87, 256.73, 299.50, 326.72]
X = np.ones((n,2))
Y = np.zeros((n,1))
Y[:,0] = np.log(y) # this is natural log
X[:,1] = x
Xt = np.transpose(X)
b = np.linalg.inv(Xt @ X) @ Xt @ Y
b
a0 = np.exp(b[0,0]) # b value
a1 = b[1,0] # a value
print(a0, a1)

def f(x): return a0 * np.exp(a1 * x)

linex = np.linspace(0, 8, 100)
liney = f(linex)


plt.scatter(x, y, marker='o')
plt.plot(linex, liney)
plt.xlabel('Value')
plt.title('Dot Plot')
plt.show()
# Out:
# 24.258760258657272 0.37238177206592904

# %% [markdown]
# The least squares approximation equation is $y = 24.258760258657272e^{0.37238177206592904x}$
